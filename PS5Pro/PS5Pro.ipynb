# %%
import pandas as pd
df = pd.read_csv('./designps5pro_allcomb.csv')
len(df['chosen_profile_id'].value_counts())
# Out:
# 101

# %%
rank = df['chosen_profile_id'].value_counts().sort_values(ascending=False)
print(rank.index.get_loc('PS5Pro'))
rank
# Out:
# 0
# chosen_profile_id
# PS5Pro    98
# PS56      96
# PS68      95
# PS61      94
# PS60      93
#           ..
# PS12      12
# PS2       11
# PS4        9
# PS1        9
# PS77       2
# Name: count, Length: 101, dtype: int64
