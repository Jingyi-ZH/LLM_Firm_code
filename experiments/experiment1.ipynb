# %%
from pathlib import Path
import os


def find_project_root(start: str | None = None) -> Path:
    start_path = Path(start or Path.cwd()).resolve()
    for p in [start_path, *start_path.parents]:
        if (p / "data_check").is_dir() and (p / "README.md").is_file():
            return p
        if (p / ".git").exists():
            return p
    return start_path


PROJECT_ROOT = find_project_root()
os.chdir(PROJECT_ROOT)
print(f"cwd set to project root: {PROJECT_ROOT}")
# Out:
# cwd set to project root: /Users/xiaobaodawang/Research/replicate/LLM_Firm_code

# %% [markdown]
# # sanity check

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-5-nano",
    input="what is your knowledge cutoff date?"
)

print(resp.output_text)
# Out:
# June 2024. I don’t have knowledge of events or developments after that date unless you share information with me.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="what are the screen sizes of all iPhone models from 11 to 15 series?"
)

print(resp.output_text)
# Out:
# Here are the screen sizes for all iPhone models from the 11 series to the 15 series:
#
# ### iPhone 11 Series:
# - **iPhone 11**: 6.1-inch Liquid Retina HD display
# - **iPhone 11 Pro**: 5.8-inch Super Retina XDR display
# - **iPhone 11 Pro Max**: 6.5-inch Super Retina XDR display
#
# ### iPhone 12 Series:
# - **iPhone 12 Mini**: 5.4-inch Super Retina XDR display
# - **iPhone 12**: 6.1-inch Super Retina XDR display
# - **iPhone 12 Pro**: 6.1-inch Super Retina XDR display
# - **iPhone 12 Pro Max**: 6.7-inch Super Retina XDR display
#
# ### iPhone 13 Series:
# - **iPhone 13 Mini**: 5.4-inch Super Retina XDR display
# - **iPhone 13**: 6.1-inch Super Retina XDR display
# - **iPhone 13 Pro**: 6.1-inch Super Retina XDR display
# - **iPhone 13 Pro Max**: 6.7-inch Super Retina XDR display
#
# ### iPhone 14 Series:
# - **iPhone 14**: 6.1-inch Super Retina XDR display
# - **iPhone 14 Plus**: 6.7-inch Super Retina XDR display
# - **iPhone 14 Pro**: 6.1-inch Super Retina XDR display
# ...

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-5-nano",
    input="what are the screen sizes of all iPhone models from 11 to 15 series?"
)

print(resp.output_text)
# Out:
# Here are the diagonal screen sizes for iPhone models from 11 through 15 (inches):
#
# - iPhone 11 — 6.1
# - iPhone 11 Pro — 5.8
# - iPhone 11 Pro Max — 6.5
# - iPhone 12 mini — 5.4
# - iPhone 12 — 6.1
# - iPhone 12 Pro — 6.1
# - iPhone 12 Pro Max — 6.7
# - iPhone 13 mini — 5.4
# - iPhone 13 — 6.1
# - iPhone 13 Pro — 6.1
# - iPhone 13 Pro Max — 6.7
# - iPhone 14 — 6.1
# - iPhone 14 Plus — 6.7
# - iPhone 14 Pro — 6.1
# - iPhone 14 Pro Max — 6.7
# - iPhone 15 — 6.1
# - iPhone 15 Plus — 6.7
# - iPhone 15 Pro — 6.1
# - iPhone 15 Pro Max — 6.7
#
# If you want this in a CSV or a quick reference sheet, I can format it that way too.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="what are the device thicknesses of all iPhone models from 11 to 15 series?"
)

print(resp.output_text)
# Out:
# Here's a list of the device thicknesses (also known as the **depth or thickness**) for each iPhone model from the iPhone 11 series through the iPhone 15 series:
#
# ### iPhone 11 series
# - **iPhone 11:** 8.3 mm
# - **iPhone 11 Pro:** 8.1 mm
# - **iPhone 11 Pro Max:** 8.1 mm
#
# ### iPhone 12 series
# - **iPhone 12 Mini:** 7.4 mm
# - **iPhone 12:** 7.4 mm
# - **iPhone 12 Pro:** 7.4 mm
# - **iPhone 12 Pro Max:** 7.4 mm
#
# ### iPhone 13 series
# - **iPhone 13 Mini:** 7.7 mm
# - **iPhone 13:** 7.7 mm
# - **iPhone 13 Pro:** 7.7 mm
# - **iPhone 13 Pro Max:** 7.65 mm
#
# ### iPhone 14 series
# - **iPhone 14:** 7.80 mm
# - **iPhone 14 Plus:** 7.80 mm
# - **iPhone 14 Pro:** 7.85 mm
# - **iPhone 14 Pro Max:** 8.25 mm
#
# ### iPhone 15 series
# (Note: As of my knowledge cutoff in 2023, these are the expected or announced specifications)
# - **iPhone 15:** ~8.25 mm (expected similar to iPhone 14 Pro Max)
# - **iPhone 15 Plus:** ~8.25 mm
# - **iPhone 15 Pro:** ~8.25 mm
# ...

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="what is your knowledge cutoff date?"
)

print(resp.output_text)
# Out:
# My knowledge cutoff date is October 2023.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="what is the latest marketing name of iPhone?"
)

print(resp.output_text)
# Out:
# As of October 2023, the latest marketing name for the newest iPhone model is the **iPhone 15 series**. The series includes different models such as the iPhone 15, iPhone 15 Plus, iPhone 15 Pro, and iPhone 15 Pro Max.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="what is your knowledge cutoff date?"
)

print(resp.output_text)
# Out:
# My knowledge cutoff date is September 2021.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="what is the latest iPhone model?"
)

print(resp.output_text)
# Out:
# As of my latest update in October 2023, the latest iPhone models are the iPhone 15 series, which includes the iPhone 15, iPhone 15 Plus, iPhone 15 Pro, and iPhone 15 Pro Max. However, Apple typically announces new iPhones in September each year, so I recommend checking the official Apple website or recent news for the most current information.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="what is your knowledge cutoff date?"
)

print(resp.output_text)
# Out:
# My knowledge cutoff date is October 2023.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="Does iPhone 15 equipped with ultrawide camera?"
)

print(resp.output_text)
# Out:
# Yes, the iPhone 15 is equipped with an ultrawide camera. The iPhone 15 series continues Apple's trend of including an ultrawide camera in its lineup, offering users the ability to capture wider photos and videos. If you'd like more specific details about the camera specifications or features of the iPhone 15, please let me know!

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="Does iPhone 16 equipped with ultrawide camera?"
)

print(resp.output_text)
# Out:
# As of now, there is no information or official announcement about the iPhone 16, including details about its camera specifications. Typically, Apple updates its iPhone models annually, and previous models have included ultrawide cameras, so it's possible that future models might continue this feature. However, for confirmed details, it's best to wait for official announcements from Apple.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="What is the next iPhone model generation?"
)

print(resp.output_text)
# Out:
# The next iPhone model generation is expected to be the iPhone 15 series. Apple typically announces new iPhones in September each year, so anticipation is building around the release of the iPhone 15 lineup. However, for the most accurate and up-to-date information, it's best to check Apple's official announcements closer to the release date.

# %%
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

resp = client.responses.create(
    model="gpt-4.1-nano",
    input="what is your expectation on device thickness of next generation iPhone?"
)

print(resp.output_text)
# Out:
# While I don't have access to unreleased product plans or confidential information, based on industry trends and previous patterns, the next-generation iPhone is likely to aim for a thinner device design. Apple has consistently worked on reducing device thickness to enhance portability and aesthetics, so expectations are that future models will feature slimmer profiles, possibly in the range of 7 to 8 millimeters, similar or slightly thinner than current models.
#
# However, any specific changes will depend on advances in internal component miniaturization, battery technology, and manufacturing innovations. Keep an eye on official announcements for precise specifications!

# %% [markdown]
# ## Note on GPT-4.1-nano knowledge cutoff
#
# OpenAI's official documentation states that GPT-4.1-nano has a knowledge cutoff of **June 2024**. However, in our sanity checks, the model self-reported inconsistent cutoff dates:
# - Responded **"October 2023"** in two out of three runs
# - Responded **"September 2021"** in one run
#
# This is completely misaligned with the official cutoff (June 2024) and indicates that **GPT-4.1-nano's self-reported knowledge cutoff is unreliable**. Furthermore, the model's response about iPhone 15 screen sizes was incomplete (missing Pro and Pro Max models) and used hedging language like "expected or latest if announced", suggesting its factual knowledge may not fully cover the period up to its official cutoff date.
#
# See `sanity_check_summary.xlsx` for the full record of all sanity check results.

# %% [markdown]
# # rank

# %%
import pandas as pd
exp1_data_folder = './output/experiment_1'
# read all csv files in exp1_data_folder
csv_files = [f for f in os.listdir(exp1_data_folder) if f.endswith('.csv')]
summary = pd.DataFrame(columns=['profile_id', 'win', 'p_win_mean', 'p_win_median'])
for i, csv_file in enumerate(csv_files):
    df = pd.read_csv(os.path.join(exp1_data_folder, csv_file))
    profile_id = csv_file.replace('_fixreal5000.csv','')
    profile_id = profile_id.replace('_',' ')
    win = len(df[df['profile_id'] == profile_id])
    p_win_mean = df[df['profile_id'] == profile_id]['prob_chosen'].mean()
    p_win_median = df[df['profile_id'] == profile_id]['prob_chosen'].median()
    row_dict = {
        'profile_id': profile_id,
        'win': win,
        'p_win_mean': p_win_mean,
        'p_win_median': p_win_median
    }
    summary = pd.concat([summary, pd.DataFrame([row_dict])], ignore_index=True)
summary['win_rate'] = summary['win'] / 5000
# Out:
# /var/folders/mj/pp0xftrd797d13_3f8ljhh600000gn/T/ipykernel_79414/2559696402.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary = pd.concat([summary, pd.DataFrame([row_dict])], ignore_index=True)

# %%
metric = 'win_rate'
summary.sort_values(by=metric, ascending=False, inplace=True)
summary.reset_index(inplace=True, drop=True)
real_summary = summary[summary['profile_id'].isin(['iPhone 16','iPhone 16 Plus', 'iPhone 16 Pro', 'iPhone 16 Pro Max', 'iPhone 17', 'iPhone 17 Air', 'iPhone 17 Pro', 'iPhone 17 Pro Max'])]
real_summary.reset_index(inplace=True)
real_summary.rename(columns={'index': f'rank_{metric}'}, inplace=True)
# Out:
# /var/folders/mj/pp0xftrd797d13_3f8ljhh600000gn/T/ipykernel_79414/2139932442.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_summary.rename(columns={'index': f'rank_{metric}'}, inplace=True)

# %%
metric = 'p_win_mean'
summary.sort_values(by=metric, ascending=False, inplace=True)
summary.reset_index(inplace=True, drop=True)
summary.reset_index(inplace=True)
summary.rename(columns={'index': f'rank_{metric}'}, inplace=True)
real_summary = real_summary.merge(summary[[f'rank_{metric}', 'profile_id']], on='profile_id', how='left')

# %%
metric = 'p_win_median'
summary.sort_values(by=metric, ascending=False, inplace=True)
summary.reset_index(inplace=True, drop=True)
summary.reset_index(inplace=True)
summary.rename(columns={'index': f'rank_{metric}'}, inplace=True)
real_summary = real_summary.merge(summary[[f'rank_{metric}', 'profile_id']], on='profile_id', how='left')

# %%
real_profiles = pd.read_csv('./experiments/alternatives/real_profiles.csv').rename(columns={'real_profile_id': 'profile_id'})
real_summary = real_summary[['profile_id','rank_p_win_mean', 'rank_p_win_median','rank_win_rate', 'win', 'p_win_mean', 'p_win_median',
       'win_rate']]
real_summary = real_summary.merge(real_profiles, on='profile_id', how='left')
for metric in ['win_rate', 'p_win_mean', 'p_win_median']:
    real_summary[f'rank_{metric}'] = real_summary[f'rank_{metric}'] + 1
real_summary
# Out:
#           profile_id  rank_p_win_mean  rank_p_win_median  rank_win_rate   win  \
# 0          iPhone 17                6                  8              7  3760
# 1      iPhone 17 Air               11                 15              9  3721
# 2      iPhone 17 Pro               21                 41             18  3480
# 3  iPhone 17 Pro Max               60                 67             22  3373
# 4          iPhone 16               17                 10             36  3043
# 5     iPhone 16 Plus               30                 30             45  2842
# 6      iPhone 16 Pro               49                 55             52  2560
# 7  iPhone 16 Pro Max               74                 75             63  2327
#
#    p_win_mean  p_win_median win_rate  battery_life  screen_size  thickness  \
# 0    0.942650      0.995391    0.752            30          6.3       7.95
# 1    0.938540      0.993307   0.7442            27          6.5       5.64
# ...

# %%
print('''r248884,36,6.1,6.0,30,48,10,equipped,9400,16,749
r440012,24,6.6,6.0,12,72,8,equipped,9400,12,849
r572725,42,6.1,6.0,30,48,5,not equipped,9400,4,949
r692659,36,6.9,6.0,24,36,3,equipped,9400,12,949
r177608,30,6.3,6.0,12,72,8,not equipped,8600,12,749
r692659,36,6.9,6.0,24,36,3,equipped,9400,12,949
iPhone 16,22,6.1,7.8,12,48,2,equipped,8205,8,899
iPhone 16 Plus,27,6.7,7.8,12,48,2,equipped,8208,8,999
iPhone 16 Pro,27,6.3,8.25,12,48,5,equipped,8581,8,1099
iPhone 16 Pro Max,33,6.9,8.25,12,48,5,equipped,8504,8,1199
iPhone 17,30,6.3,7.95,18,48,2,equipped,9191,8,799
iPhone 17 Air,27,6.5,5.64,18,48,2,not equipped,9323,12,999
iPhone 17 Pro,33,6.3,8.75,18,48,8,equipped,9737,12,1099
iPhone 17 Pro Max,39,6.9,8.75,18,48,8,equipped,9776,12,1199''')
# Out:
# r248884,36,6.1,6.0,30,48,10,equipped,9400,16,749
# r440012,24,6.6,6.0,12,72,8,equipped,9400,12,849
# r572725,42,6.1,6.0,30,48,5,not equipped,9400,4,949
# r692659,36,6.9,6.0,24,36,3,equipped,9400,12,949
# r177608,30,6.3,6.0,12,72,8,not equipped,8600,12,749
# r692659,36,6.9,6.0,24,36,3,equipped,9400,12,949
# iPhone 16,22,6.1,7.8,12,48,2,equipped,8205,8,899
# iPhone 16 Plus,27,6.7,7.8,12,48,2,equipped,8208,8,999
# iPhone 16 Pro,27,6.3,8.25,12,48,5,equipped,8581,8,1099
# iPhone 16 Pro Max,33,6.9,8.25,12,48,5,equipped,8504,8,1199
# iPhone 17,30,6.3,7.95,18,48,2,equipped,9191,8,799
# iPhone 17 Air,27,6.5,5.64,18,48,2,not equipped,9323,12,999
# iPhone 17 Pro,33,6.3,8.75,18,48,8,equipped,9737,12,1099
# iPhone 17 Pro Max,39,6.9,8.75,18,48,8,equipped,9776,12,1199

# %%
real_summary[['profile_id', 'rank_p_win_mean', 'rank_p_win_median', 'rank_win_rate']]

# %% [markdown]
# ## Conclusions
#
# 1. Most attributes have a relatively **uniform** influence on win_rate / prob, but the model clearly **favors high Geekbench scores** and **low price**. These two attributes appear to be the strongest drivers of preference.
#
# 2. Top-ranked profiles tend to have **very low device thickness** — this likely explains why **iPhone 17 Air** (5.64 mm, the thinnest by far) ranks surprisingly high (rank 9 by win_rate, rank 11 by p_win_mean) despite not being equipped with an ultrawide camera.
#
# 3. **High Geekbench scores favor the entire iPhone 17 series**: all four iPhone 17 models (Geekbench 9191–9776) rank above their iPhone 16 counterparts (Geekbench 8205–8581) across all three metrics (win_rate, p_win_mean, p_win_median). The generational Geekbench gap (~600–1200 points) appears to be a major differentiator.
